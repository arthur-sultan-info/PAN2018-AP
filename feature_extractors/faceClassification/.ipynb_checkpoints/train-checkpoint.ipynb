# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split

import seaborn as sns
sns.set_style('white')

# %%
# load features and labels
df_feat = pd.read_csv('feature.csv', index_col=0)
df_label = pd.read_csv('label.csv', index_col=0)

# %%
# split training/test name
unique_names = list(set([path.split('/')[0] for path in df_feat.index]))
name_train, name_test = train_test_split(unique_names, test_size = 0.1, random_state = 0)
name_train, name_test = set(name_train), set(name_test)
# split training/test images
idx_train = [path.split('/')[0] in name_train for path in df_feat.index]
idx_test = [path.split('/')[0] in name_test for path in df_feat.index]
X_train, Y_train = df_feat[idx_train], df_label[idx_train]
X_test, Y_test = df_feat[idx_test], df_label[idx_test]

# %%
clf = MLPClassifier(solver='adam', hidden_layer_sizes=(128, 128),max_iter = 5000, verbose=True, tol=1e-4, activation='relu')
clf.fit(X_train, Y_train)
pred = clf.predict(X_test)
score = clf.predict_proba(X_test)

df_pred = pd.DataFrame(pred, columns=df_label.columns, index=Y_test.index)
df_score = pd.DataFrame(score, columns=df_label.columns, index=Y_test.index)
# Out:
# Iteration 1, loss = 40.84669541
# Iteration 2, loss = 35.12694359
# Iteration 3, loss = 33.03828006
# Iteration 4, loss = 32.04214812
# Iteration 5, loss = 31.41121305
# Iteration 6, loss = 30.98198194
# Iteration 7, loss = 30.69693003
# Iteration 8, loss = 30.48571727
# Iteration 9, loss = 30.33060471
# Iteration 10, loss = 30.13497261
# Iteration 11, loss = 29.98680539
# Iteration 12, loss = 29.82972628
# Iteration 13, loss = 29.69361278
# Iteration 14, loss = 29.57761320
# Iteration 15, loss = 29.45374944
# Iteration 16, loss = 29.34311328
# Iteration 17, loss = 29.24689990
# Iteration 18, loss = 29.16895742
# Iteration 19, loss = 29.08196486
# Iteration 20, loss = 29.01729442
# Iteration 21, loss = 28.96224453
# Iteration 22, loss = 28.90581704
# Iteration 23, loss = 28.87123477
# Iteration 24, loss = 28.81661870
# Iteration 25, loss = 28.76848145
# Iteration 26, loss = 28.72426329
# Iteration 27, loss = 28.68136398
# Iteration 28, loss = 28.63810387
# Iteration 29, loss = 28.60538560
# Iteration 30, loss = 28.57815101
# Iteration 31, loss = 28.53753271
# Iteration 32, loss = 28.51608570
# Iteration 33, loss = 28.51249384
# Iteration 34, loss = 28.44979648
# Iteration 35, loss = 28.41668471
# Iteration 36, loss = 28.38465199
# Iteration 37, loss = 28.35939045
# Iteration 38, loss = 28.33910518
# Iteration 39, loss = 28.33250560
# Iteration 40, loss = 28.29376298
# Iteration 41, loss = 28.24024318
# Iteration 42, loss = 28.22061542
# Iteration 43, loss = 28.19627102
# Iteration 44, loss = 28.17370066
# Iteration 45, loss = 28.19279848
# Iteration 46, loss = 28.12482829
# Iteration 47, loss = 28.07929532
# Iteration 48, loss = 28.05904504
# Iteration 49, loss = 28.04956968
# Iteration 50, loss = 28.01264734
# Iteration 51, loss = 27.99756395
# Iteration 52, loss = 27.96374229
# Iteration 53, loss = 27.95241507
# Iteration 54, loss = 27.91007487
# Iteration 55, loss = 27.89862497
# Iteration 56, loss = 27.86480700
# Iteration 57, loss = 27.85955124
# Iteration 58, loss = 27.81047550
# Iteration 59, loss = 27.79246381
# Iteration 60, loss = 27.80349847
# Iteration 61, loss = 27.77114371
# Iteration 62, loss = 27.73247604
# Iteration 63, loss = 27.70362154
# Iteration 64, loss = 27.68549369
# Iteration 65, loss = 27.68460530
# Iteration 66, loss = 27.63440745
# Iteration 67, loss = 27.62489214
# Iteration 68, loss = 27.61130024
# Iteration 69, loss = 27.62790325
# Iteration 70, loss = 27.56035758
# Iteration 71, loss = 27.55805307
# Iteration 72, loss = 27.52280136
# Iteration 73, loss = 27.49835263
# Iteration 74, loss = 27.47730029
# Iteration 75, loss = 27.51085011
# Iteration 76, loss = 27.44896389
# Iteration 77, loss = 27.42750137
# Iteration 78, loss = 27.39777376
# Iteration 79, loss = 27.40285299
# Iteration 80, loss = 27.38264267
# Iteration 81, loss = 27.34386438
# Iteration 82, loss = 27.33562225
# Iteration 83, loss = 27.31250379
# Iteration 84, loss = 27.33346222
# Iteration 85, loss = 27.28229145
# Iteration 86, loss = 27.26031404
# Iteration 87, loss = 27.25250089
# Iteration 88, loss = 27.21931862
# Iteration 89, loss = 27.23103207
# Iteration 90, loss = 27.19945366
# Iteration 91, loss = 27.19815668
# Iteration 92, loss = 27.17959022
# Iteration 93, loss = 27.18820611
# Iteration 94, loss = 27.15801267
# Iteration 95, loss = 27.12543487
# Iteration 96, loss = 27.12419830
# Iteration 97, loss = 27.09477022
# Iteration 98, loss = 27.07298845
# Iteration 99, loss = 27.07813439
# Iteration 100, loss = 27.03643765
# Iteration 101, loss = 27.05065880
# Iteration 102, loss = 27.03167737
# Iteration 103, loss = 27.00687582
# Iteration 104, loss = 26.99980570
# Iteration 105, loss = 26.99018565
# Iteration 106, loss = 26.96862670
# Iteration 107, loss = 26.97400376
# Iteration 108, loss = 26.96007540
# Iteration 109, loss = 26.93462545
# Iteration 110, loss = 26.90911215
# Iteration 111, loss = 26.90292574
# Iteration 112, loss = 26.89311748
# Iteration 113, loss = 26.88483933
# Iteration 114, loss = 26.87467385
# Iteration 115, loss = 26.86691989
# Iteration 116, loss = 26.84923006
# Iteration 117, loss = 26.83167950
# Iteration 118, loss = 26.82178792
# Iteration 119, loss = 26.82312198
# Iteration 120, loss = 26.81071608
# Iteration 121, loss = 26.78724859
# Iteration 122, loss = 26.79681664
# Iteration 123, loss = 26.79378444
# Iteration 124, loss = 26.73639912
# Iteration 125, loss = 26.75334092
# Iteration 126, loss = 26.75440275
# Iteration 127, loss = 26.71192826
# Iteration 128, loss = 26.73651685
# Iteration 129, loss = 26.76362341
# Iteration 130, loss = 26.67146185
# Iteration 131, loss = 26.68910768
# Iteration 132, loss = 26.66496728
# Iteration 133, loss = 26.66243881
# Iteration 134, loss = 26.63016722
# Iteration 135, loss = 26.64079035
# Iteration 136, loss = 26.65923991
# Iteration 137, loss = 26.61903181
# Iteration 138, loss = 26.60329657
# Iteration 139, loss = 26.58283628
# Iteration 140, loss = 26.61813855
# Iteration 141, loss = 26.61888362
# Iteration 142, loss = 26.54812768
# Iteration 143, loss = 26.52900976
# Iteration 144, loss = 26.53672512
# Iteration 145, loss = 26.52354546
# Iteration 146, loss = 26.53068376
# Iteration 147, loss = 26.51529921
# Iteration 148, loss = 26.48586576
# Iteration 149, loss = 26.50107718
# Iteration 150, loss = 26.49414892
# Iteration 151, loss = 26.52322188
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.

# %%
# save model
import pickle
save_path = 'face_model.pkl'
with open(save_path, 'wb') as f:
    pickle.dump([clf, df_label.columns.tolist()], f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-b9d9fc076965> in <module>()
#       3 save_path = 'face_model.pkl'
#       4 with open(save_path, 'w') as f:
# ----> 5     pickle.dump([clf, df_label.columns.tolist()], f)
#
# TypeError: write() argument must be str, not bytes

# %%
def plot_roc(attr, target, score):
    """Plot a ROC curve and show the accuracy score and the AUC"""
    fig, ax = plt.subplots()
    auc = roc_auc_score(target, score)
    acc = accuracy_score(target, (score >= 0.5).astype(int))
    fpr, tpr, _ = roc_curve(target, score)
    plt.plot(fpr, tpr, lw = 2, label = attr.title())
    plt.legend(loc = 4, fontsize = 15)
    plt.title(('ROC Curve for {attr} (Accuracy = {acc:.3f}, AUC = {auc:.3f})'
               .format(attr = attr.title(), acc= acc, auc = auc)),
              fontsize = 15)
    plt.xlabel('False Positive Rate', fontsize = 15)
    plt.ylabel('True Positive Rate', fontsize = 15)
    plt.show()
    return fig

# %%
# plot ROC curves
cols = ['Male', 'Asian', 'Black', 'White']
for attr in cols:
    target = Y_test[attr]
    score = df_score[attr]
    fig = plot_roc(attr, target, score)
